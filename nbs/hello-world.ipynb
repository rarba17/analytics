# %%
print("hell")
# !pip install requests
# Out:
# hell
# Requirement already satisfied: requests in /home/abrar/Desktop/analytics/venv/lib/python3.13/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/abrar/Desktop/analytics/venv/lib/python3.13/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/abrar/Desktop/analytics/venv/lib/python3.13/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/abrar/Desktop/analytics/venv/lib/python3.13/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/abrar/Desktop/analytics/venv/lib/python3.13/site-packages (from requests) (2025.11.12)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import requests
path = "/healthz"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/healthz'

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# True
