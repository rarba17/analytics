# %%
import requests
path = "/api/events/"
base_url = " http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# ' http://localhost:8002/api/events/'

# %%
data = {"page":"/test+"}

# %%
import json
json.dumps(data)
# Out:
# '{"page": "/test+"}'

# %%
headers = {
  "Content-Type": "application/json"
}
response = requests.post(endpoint, data=json.dumps(data), headers=headers)
print(response.headers)
print('ok', response.ok)
if response.ok:
  data = response.json()
  print(data, type(data), data.get('items'))
else:
  print(response.text)
# Out:
# {'date': 'Sat, 06 Dec 2025 14:11:51 GMT', 'server': 'uvicorn', 'content-length': '10', 'content-type': 'application/json'}
# ok True
# {'id': 123} <class 'dict'> None

# %%
detailed_path = "/api/events/12/"
detail_endpoint = f"{base_url}{detailed_path}"
detail_endpoint


response = requests.put(detail_endpoint, json={"description":"hellowrld"})
print(response.headers)
print('ok', response.ok)
if response.ok:
  data = response.json()
  print(data, type(data), data.get('items'))
else:
  print(response.text)
# Out:
# {'date': 'Sat, 06 Dec 2025 14:25:43 GMT', 'server': 'uvicorn', 'content-length': '45', 'content-type': 'application/json'}
# ok True
# {'id': 12, 'page': '', 'description': 'hellowrld'} <class 'dict'> None
